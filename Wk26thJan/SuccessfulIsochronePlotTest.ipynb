# %%
import os
os.environ["PYTHONIOENCODING"] = "utf-8"

import ezpadova
import matplotlib.pyplot as plt

# 1. Fetch data (Run this if 'df' isn't in memory yet)
# Note: Since your previous output showed Bmag/Vmag, we use the default system
df = ezpadova.get_one_isochrone(logage=9.0, Z=0.0152, label='parsec_v12s')

# 2. Plotting
plt.figure(figsize=(8, 10))

# Using the columns confirmed in your 'Available columns' list
color = df['Bmag'] - df['Vmag']
magnitude = df['Vmag']

plt.scatter(color, magnitude, color='firebrick', lw=2, label='1 Gyr PARSEC')

# Formatting
plt.gca().invert_yaxis() 
plt.xlabel('B - V (Color Index)', fontsize=12)
plt.ylabel('$M_V$ (Absolute Magnitude)', fontsize=12)
plt.title('PARSEC Isochrone: 1 Gyr ($log_{10}t = 9$)', fontsize=14)
plt.grid(True, linestyle=':', alpha=0.7)
plt.legend()

plt.show()
# Out:
# Querying http://stev.oapd.inaf.it/cgi-bin/cmd...
# Retrieving data...
# Downloading data...http://stev.oapd.inaf.it/tmp/output833983501958.dat
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[3], line 9
#       5 '''import matplotlib.pyplot as plt'''
#       7 # 1. Fetch data (Run this if 'df' isn't in memory yet)
#       8 # Note: Since your previous output showed Bmag/Vmag, we use the default system
# ----> 9 df = ezpadova.get_one_isochrone(logage=9.0, Z=0.0152, label='parsec_v12s')
#      11 # 2. Plotting
#      12 '''plt.figure(figsize=(8, 10))'''
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ezpadova\tools.py:93, in deprecated_replacedby.<locals>.decorator.<locals>.new_func(*args, **kwargs)
#      90 @wraps(func)
#      91 def new_func(*args, **kwargs):
#      92     warnings.warn(msg, DeprecationWarning)
# ---> 93     return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ezpadova\deprecated.py:61, in get_one_isochrone(age_yr, Z, logage, MH, ret_table, **kwargs)
#      58 else:
#      59     query["MH"] = [MH, MH, 0]
# ---> 61 return get_isochrones(return_df=ret_table, **query, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ezpadova\parsec.py:240, in get_isochrones(age_yr, Z, logage, MH, default_ranges, return_df, **kwargs)
#     238 # parse to dataframe if requested (default)
#     239 if return_df:
# --> 240     return parse_result(res)
#     241 else:
#     242     return res
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ezpadova\parsec.py:84, in parse_result(data, comment)
#      82 split_txt = data.decode("utf-8").split("\n")
#      83 for num, line in enumerate(split_txt):
# ---> 84     if line[0] != comment:
#      85         break
#      86 start = num - 1
#
# IndexError: string index out of range
