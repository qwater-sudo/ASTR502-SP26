# %%
# Import necassary libraries and functions
import os
os.environ["PYTHONIOENCODING"] = "utf-8"

import ezpadova
from ezpadova import parsec
from astropy.table import Table
import numpy as np 
import pandas as pd

# %%
# Test file
df = ezpadova.get_isochrones(age_yr=(1e9, 5e9, 1e9), MH=(0.0, 0.0, 0.0), phot_system='GAIAEDR3')

# %%
# Saving test file to fits
table = Table.from_pandas(df)
table.write('my_isochrones.fits', overwrite=True)
